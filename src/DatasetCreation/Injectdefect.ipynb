# %%
import os
import glob
import nibabel as nib
import numpy as np
import random

def generate_chest_defect(data, cube_dim):
    
    x_, y_, z_ = data.shape
    chest_start = int(z_ * 0.5)  # Startin at the middle of the z-dimension, assuming the chest is in the upper half
    chest_end = int(z_ * 0.75)   # Extend to three-quarters of the z-dimension

    full_masking = np.ones(shape=(x_, y_, z_))
    x = random.randint(int(cube_dim / 2), x_ - int(cube_dim / 2))
    y = random.randint(int(cube_dim / 2), y_ - int(cube_dim / 2))
    z = random.randint(chest_start, chest_end)

    cube_masking = np.zeros(shape=(cube_dim, cube_dim, z_ - z))
    full_masking[x - int(cube_dim / 2):x + int(cube_dim / 2),
                 y - int(cube_dim / 2):y + int(cube_dim / 2),
                 z:z_] = cube_masking

    # defected data
    defected_data = full_masking * data
    # implant data
    implant_data = (1 - full_masking) * data

    return defected_data, implant_data

def process_segmented_files(file_path, cube_dim, defected_dir, implant_dir):
    """Process a single .nii file to introduce a defect and save it, along with the extracted defect."""
    nii_img = nib.load(file_path)
    data = nii_img.get_fdata()
    affine = nii_img.affine
    header = nii_img.header

    defected_data, implant_data = generate_chest_defect(data, cube_dim)

    # Save the defected data and implant
    file_name = os.path.basename(file_path)
    base_name, _ = os.path.splitext(file_name)
    #print(file_name,base_name[:-10])
    defected_path = os.path.join(defected_dir, base_name[:-10] + '_defected.nii.gz')
    implant_path = os.path.join(implant_dir, base_name[:-10] + '_implant.nii.gz')

    defected_img = nib.Nifti1Image(defected_data, affine, header)
    nib.save(defected_img, defected_path)
    print(f"Processed and saved defected: {defected_path}")

    implant_img = nib.Nifti1Image(implant_data, affine, header)
    nib.save(implant_img, implant_path)
    print(f"Processed and saved implant: {implant_path}")

def main(segmented_dir, defected_dir, implant_dir, cube_dim):
    """Main function to process all segmented .nii files to introduce defects and save implants."""
    nii_files = glob.glob(os.path.join(segmented_dir, '*.nii')) + glob.glob(os.path.join(segmented_dir, '*.nii.gz'))
    os.makedirs(defected_dir, exist_ok=True)
    os.makedirs(implant_dir, exist_ok=True)

    for nii_file in nii_files:
        print(f"Processing file: {nii_file}")
        process_segmented_files(nii_file, cube_dim, defected_dir, implant_dir)

    print(f"Processing complete. Results saved in: {defected_dir} and {implant_dir}")

if __name__ == "__main__":
    # Directory containing the segmented files
    segmented_dir = '/workspace/RibCage/val-segmented_ribfrac'  
    defected_dir = '/workspace/RibCage/val-ribfrac-defected-new1'  
    implant_dir = '/workspace/RibCage/val-ribfrac-implants-new1'  
    cube_dim = 64 

    main(segmented_dir, defected_dir, implant_dir, cube_dim)
# Out:
# Processing file: /workspace/RibCage/val-segmented_ribfrac/RibFrac438-image.nii.gz
# Processed and saved defected: /workspace/RibCage/val-ribfrac-defected-new1/RibFrac438_defected.nii.gz
# Processed and saved implant: /workspace/RibCage/val-ribfrac-implants-new1/RibFrac438_implant.nii.gz
# Processing file: /workspace/RibCage/val-segmented_ribfrac/RibFrac441-image.nii.gz
# Processed and saved defected: /workspace/RibCage/val-ribfrac-defected-new1/RibFrac441_defected.nii.gz
# Processed and saved implant: /workspace/RibCage/val-ribfrac-implants-new1/RibFrac441_implant.nii.gz
# Processing file: /workspace/RibCage/val-segmented_ribfrac/RibFrac491-image.nii.gz
# Processed and saved defected: /workspace/RibCage/val-ribfrac-defected-new1/RibFrac491_defected.nii.gz
# Processed and saved implant: /workspace/RibCage/val-ribfrac-implants-new1/RibFrac491_implant.nii.gz
# Processing file: /workspace/RibCage/val-segmented_ribfrac/RibFrac421-image.nii.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 73
#      70 implant_dir = '/workspace/RibCage/val-ribfrac-implants-new1'
#      71 cube_dim = 64
# ---> 73 main(segmented_dir, defected_dir, implant_dir, cube_dim)
#
# Cell In[2], line 62, in main(segmented_dir, defected_dir, implant_dir, cube_dim)
#      60 for nii_file in nii_files:
#      61     print(f"Processing file: {nii_file}")
# ---> 62     process_segmented_files(nii_file, cube_dim, defected_dir, implant_dir)
#      64 print(f"Processing complete. Results saved in: {defected_dir} and {implant_dir}")
#
# Cell In[2], line 47, in process_segmented_files(file_path, cube_dim, defected_dir, implant_dir)
#      44 implant_path = os.path.join(implant_dir, base_name[:-10] + '_implant.nii.gz')
#      46 defected_img = nib.Nifti1Image(defected_data, affine, header)
# ---> 47 nib.save(defected_img, defected_path)
#      48 print(f"Processed and saved defected: {defected_path}")
#      50 implant_img = nib.Nifti1Image(implant_data, affine, header)
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/loadsave.py:163, in save(img, filename, **kwargs)
#     161 # Save the type as expected
#     162 try:
# --> 163     img.to_filename(filename, **kwargs)
#     164 except ImageFileError:
#     165     pass
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/filebasedimages.py:307, in FileBasedImage.to_filename(self, filename, **kwargs)
#     291 r"""Write image to files implied by filename string
#     292
#     293 Parameters
#    (...)
#     304 None
#     305 """
#     306 self.file_map = self.filespec_to_file_map(filename)
# --> 307 self.to_file_map(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/nifti1.py:2217, in Nifti1Pair.to_file_map(self, file_map, dtype)
#    2215 self.get_data_dtype(finalize=True)
#    2216 try:
# -> 2217     super().to_file_map(file_map, dtype)
#    2218 finally:
#    2219     self.set_data_dtype(img_dtype)
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/analyze.py:1051, in AnalyzeImage.to_file_map(self, file_map, dtype)
#    1049 seek_tell(imgf, hdr.get_data_offset(), write0=True)
#    1050 # Write array data
# -> 1051 arr_writer.to_fileobj(imgf)
#    1052 hdrf.close_if_mine()
#    1053 if not hdr_img_same:
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/arraywriters.py:525, in SlopeInterArrayWriter.to_fileobj(self, fileobj, order)
#     516 """Write array into `fileobj`
#     517
#     518 Parameters
#    (...)
#     522     order (Fortran or C) to which to write array
#     523 """
#     524 mn, mx = self._writing_range()
# --> 525 array_to_file(
#     526     self._array,
#     527     fileobj,
#     528     self._out_dtype,
#     529     offset=None,
#     530     intercept=self.inter,
#     531     divslope=self.slope,
#     532     mn=mn,
#     533     mx=mx,
#     534     order=order,
#     535     nan2zero=self._needs_nan2zero(),
#     536 )
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/volumeutils.py:705, in array_to_file(data, fileobj, out_dtype, offset, intercept, divslope, mn, mx, order, nan2zero)
#     703 post_mx = np.min([post_mx, both_mx])
#     704 in_cast = None if cast_in_dtype == in_dtype else cast_in_dtype
# --> 705 return _write_data(
#     706     data,
#     707     fileobj,
#     708     out_dtype,
#     709     order,
#     710     in_cast=in_cast,
#     711     pre_clips=pre_clips,
#     712     inter=inter,
#     713     slope=slope,
#     714     post_clips=(post_mn, post_mx),
#     715     nan_fill=nan_fill if nan2zero else None,
#     716 )
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/volumeutils.py:784, in _write_data(data, fileobj, out_dtype, order, in_cast, pre_clips, inter, slope, post_clips, nan_fill)
#     782 if dslice.dtype != out_dtype:
#     783     dslice = dslice.astype(out_dtype)
# --> 784 fileobj.write(dslice.tobytes())
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/openers.py:232, in Opener.write(self, b)
#     231 def write(self, b: bytes, /) -> int | None:
# --> 232     return self.fobj.write(b)
#
# File /opt/conda/lib/python3.10/gzip.py:289, in GzipFile.write(self, data)
#     286     length = data.nbytes
#     288 if length > 0:
# --> 289     self.fileobj.write(self.compress.compress(data))
#     290     self.size += length
#     291     self.crc = zlib.crc32(data, self.crc)
#
# KeyboardInterrupt:
