# %%
import cc3d
import numpy as np
import nibabel as nib
import os
import shutil
import zipfile
import glob

def identify_largest_component(labels_out):
    labels_out = labels_out.ravel()
    label, counts = np.unique(labels_out, return_counts=True)
    
    # Ignore the background label (0)
    label_counts = dict(zip(label, counts))
    label_counts.pop(0, None)
    
    # Find the label with the largest count
    largest_label = max(label_counts, key=label_counts.get)
    print('Largest connected component label:', largest_label)
    return largest_label

def denoise_nifti(file_path, save_dir):
    """Denoise a NIfTI file by keeping only the largest connected component."""
    # Load the .nii file
    nii_img = nib.load(file_path)
    data = nii_img.get_fdata()
    affine = nii_img.affine
    header = nii_img.header
    
    # Get all connected components
    labels_out = cc3d.connected_components(data.astype('int32'))

    # Identify the largest connected component (assumed to be the ribcage)
    largest_label = identify_largest_component(labels_out)
    
    # Keep only the largest connected component
    cleaned_data = (labels_out == largest_label).astype(np.uint8)
    
    # Save the cleaned data to a new .nii file
    filename = os.path.basename(file_path).replace('.nii', '_cleaned.nii')
    save_path = os.path.join(save_dir, filename)
    cleaned_img = nib.Nifti1Image(cleaned_data, affine, header)
    nib.save(cleaned_img, save_path)
    print(f"Denoised and saved: {save_path}")

def main(zip_file_path, save_dir):

    # Process each .nii file one by one using glob
    nii_files = glob.glob(os.path.join(segmented_dir, '*.nii')) + glob.glob(os.path.join(segmented_dir, '*.nii.gz'))
    os.makedirs(save_dir, exist_ok=True)
    
    for nii_file in nii_files:
        print(f"Processing file: {nii_file}")
        denoise_nifti(nii_file, save_dir)
    
    # Clean up the extraction directory
    shutil.rmtree(extract_dir)
    print(f"Denoising complete. Results saved in: {save_dir}")

if __name__ == "__main__":
    segmented_dir = '/workspace/RibCage/segmented_ribfrac' 
    save_dir = '/workspace/RibCage/cleaned_ribcage'

    main(segmented_dir, save_dir)
# Out:
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac525-image.nii.gz
# Largest connected component label: 1690320
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac525-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac569-image.nii.gz
# Largest connected component label: 183083
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac569-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac523-image.nii.gz
# Largest connected component label: 972236
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac523-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac613-image.nii.gz
# Largest connected component label: 573986
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac613-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac551-image.nii.gz
# Largest connected component label: 4657987
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac551-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac622-image.nii.gz
# Largest connected component label: 656318
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac622-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac579-image.nii.gz
# Largest connected component label: 1790119
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac579-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac616-image.nii.gz
# Largest connected component label: 1871278
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac616-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac617-image.nii.gz
# Largest connected component label: 3238798
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac617-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac618-image.nii.gz
# Largest connected component label: 933856
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac618-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac549-image.nii.gz
# Largest connected component label: 54
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac549-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac527-image.nii.gz
# Largest connected component label: 1092743
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac527-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac633-image.nii.gz
# Largest connected component label: 4019619
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac633-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac625-image.nii.gz
# Largest connected component label: 795644
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac625-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac537-image.nii.gz
# Largest connected component label: 992858
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac537-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac644-image.nii.gz
# Largest connected component label: 1064675
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac644-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac589-image.nii.gz
# Largest connected component label: 1510884
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac589-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac636-image.nii.gz
# Largest connected component label: 460750
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac636-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac614-image.nii.gz
# Largest connected component label: 2121456
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac614-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac502-image.nii.gz
# Largest connected component label: 3073250
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac502-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac503-image.nii.gz
# Largest connected component label: 511207
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac503-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac564-image.nii.gz
# Largest connected component label: 833499
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac564-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac550-image.nii.gz
# Largest connected component label: 922973
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac550-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac648-image.nii.gz
# Largest connected component label: 2545664
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac648-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac624-image.nii.gz
# Largest connected component label: 956081
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac624-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac620-image.nii.gz
# Largest connected component label: 5993559
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac620-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac581-image.nii.gz
# Largest connected component label: 543503
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac581-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac531-image.nii.gz
# Largest connected component label: 350317
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac531-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac510-image.nii.gz
# Largest connected component label: 1245889
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac510-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac512-image.nii.gz
# Largest connected component label: 1049592
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac512-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac575-image.nii.gz
# Largest connected component label: 1738534
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac575-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac591-image.nii.gz
# Largest connected component label: 832432
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac591-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac509-image.nii.gz
# Largest connected component label: 1749570
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac509-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac580-image.nii.gz
# Largest connected component label: 3828931
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac580-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac528-image.nii.gz
# Largest connected component label: 538839
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac528-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac639-image.nii.gz
# Largest connected component label: 124068
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac639-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac593-image.nii.gz
# Largest connected component label: 907841
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac593-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac541-image.nii.gz
# Largest connected component label: 3234440
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac541-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac505-image.nii.gz
# Largest connected component label: 765565
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac505-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac604-image.nii.gz
# Largest connected component label: 1128452
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac604-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac650-image.nii.gz
# Largest connected component label: 353728
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac650-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac556-image.nii.gz
# Largest connected component label: 299789
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac556-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac652-image.nii.gz
# Largest connected component label: 1579037
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac652-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac526-image.nii.gz
# Largest connected component label: 2933637
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac526-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac609-image.nii.gz
# Largest connected component label: 1561134
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac609-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac659-image.nii.gz
# Largest connected component label: 1753498
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac659-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac657-image.nii.gz
# Largest connected component label: 894
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac657-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac631-image.nii.gz
# Largest connected component label: 2251444
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac631-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac535-image.nii.gz
# Largest connected component label: 1934728
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac535-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac585-image.nii.gz
# Largest connected component label: 1543241
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac585-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac642-image.nii.gz
# Largest connected component label: 1796458
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac642-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac544-image.nii.gz
# Largest connected component label: 3280430
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac544-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac521-image.nii.gz
# Largest connected component label: 1947687
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac521-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac529-image.nii.gz
# Largest connected component label: 1579890
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac529-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac563-image.nii.gz
# Largest connected component label: 889869
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac563-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac566-image.nii.gz
# Largest connected component label: 3372561
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac566-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac524-image.nii.gz
# Largest connected component label: 511254
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac524-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac530-image.nii.gz
# Largest connected component label: 1889836
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac530-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac653-image.nii.gz
# Largest connected component label: 670391
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac653-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac507-image.nii.gz
# Largest connected component label: 6623526
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac507-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac632-image.nii.gz
# Largest connected component label: 1012258
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac632-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac511-image.nii.gz
# Largest connected component label: 3052532
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac511-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac517-image.nii.gz
# Largest connected component label: 3083366
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac517-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac571-image.nii.gz
# Largest connected component label: 885247
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac571-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac508-image.nii.gz
# Largest connected component label: 3317015
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac508-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac655-image.nii.gz
# Largest connected component label: 1637417
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac655-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac543-image.nii.gz
# Largest connected component label: 5108439
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac543-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac576-image.nii.gz
# Largest connected component label: 1924803
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac576-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac515-image.nii.gz
# Largest connected component label: 416743
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac515-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac553-image.nii.gz
# Largest connected component label: 6
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac553-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac572-image.nii.gz
# Largest connected component label: 858387
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac572-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac532-image.nii.gz
# Largest connected component label: 2774574
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac532-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac623-image.nii.gz
# Largest connected component label: 3272921
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac623-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac534-image.nii.gz
# Largest connected component label: 1874573
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac534-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac577-image.nii.gz
# Largest connected component label: 4743479
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac577-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac586-image.nii.gz
# Largest connected component label: 1439676
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac586-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac501-image.nii.gz
# Largest connected component label: 2596718
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac501-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac599-image.nii.gz
# Largest connected component label: 1806937
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac599-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac654-image.nii.gz
# Largest connected component label: 485
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac654-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac519-image.nii.gz
# Largest connected component label: 851465
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac519-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac583-image.nii.gz
# Largest connected component label: 1773966
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac583-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac560-image.nii.gz
# Largest connected component label: 130190
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac560-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac595-image.nii.gz
# Largest connected component label: 137711
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac595-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac558-image.nii.gz
# Largest connected component label: 820217
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac558-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac626-image.nii.gz
# Largest connected component label: 2445866
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac626-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac619-image.nii.gz
# Largest connected component label: 1330734
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac619-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac547-image.nii.gz
# Largest connected component label: 2162670
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac547-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac518-image.nii.gz
# Largest connected component label: 1092198
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac518-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac645-image.nii.gz
# Largest connected component label: 585156
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac645-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac598-image.nii.gz
# Largest connected component label: 4318800
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac598-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac656-image.nii.gz
# Largest connected component label: 2808496
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac656-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac574-image.nii.gz
# Largest connected component label: 1943858
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac574-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac658-image.nii.gz
# Largest connected component label: 3272994
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac658-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac601-image.nii.gz
# Largest connected component label: 2420855
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac601-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac588-image.nii.gz
# Largest connected component label: 974004
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac588-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac504-image.nii.gz
# Largest connected component label: 110075
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac504-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac612-image.nii.gz
# Largest connected component label: 2137680
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac612-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac557-image.nii.gz
# Largest connected component label: 1330453
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac557-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac545-image.nii.gz
# Largest connected component label: 1479670
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac545-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac647-image.nii.gz
# Largest connected component label: 1354786
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac647-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac562-image.nii.gz
# Largest connected component label: 1332532
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac562-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac506-image.nii.gz
# Largest connected component label: 3111481
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac506-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac634-image.nii.gz
# Largest connected component label: 849516
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac634-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac627-image.nii.gz
# Largest connected component label: 1176573
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac627-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac637-image.nii.gz
# Largest connected component label: 674500
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac637-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac649-image.nii.gz
# Largest connected component label: 158175
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac649-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac646-image.nii.gz
# Largest connected component label: 561658
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac646-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac640-image.nii.gz
# Largest connected component label: 1434375
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac640-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac610-image.nii.gz
# Largest connected component label: 2300725
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac610-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac629-image.nii.gz
# Largest connected component label: 4471628
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac629-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac605-image.nii.gz
# Largest connected component label: 1607874
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac605-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac555-image.nii.gz
# Largest connected component label: 2980465
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac555-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac513-image.nii.gz
# Largest connected component label: 1964557
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac513-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac520-image.nii.gz
# Largest connected component label: 2051559
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac520-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac635-image.nii.gz
# Largest connected component label: 1935706
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac635-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac522-image.nii.gz
# Largest connected component label: 2267235
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac522-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac597-image.nii.gz
# Largest connected component label: 5072846
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac597-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac607-image.nii.gz
# Largest connected component label: 3117503
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac607-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac615-image.nii.gz
# Largest connected component label: 3667629
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac615-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac552-image.nii.gz
# Largest connected component label: 409713
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac552-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac578-image.nii.gz
# Largest connected component label: 1062732
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac578-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac621-image.nii.gz
# Largest connected component label: 1083766
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac621-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac660-image.nii.gz
# Largest connected component label: 1635451
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac660-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac548-image.nii.gz
# Largest connected component label: 2835860
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac548-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac539-image.nii.gz
# Largest connected component label: 1947066
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac539-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac587-image.nii.gz
# Largest connected component label: 3231939
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac587-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac630-image.nii.gz
# Largest connected component label: 2175936
# Denoised and saved: /workspace/RibCage/cleaned_ribcage/RibFrac630-image_cleaned.nii.gz
# Processing file: /workspace/RibCage/segmented_ribfrac/RibFrac538-image.nii.gz
